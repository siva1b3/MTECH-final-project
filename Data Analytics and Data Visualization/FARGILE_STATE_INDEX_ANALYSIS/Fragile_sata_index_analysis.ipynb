# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.rcParams['figure.figsize']=(12,7)

# %%
df = pd.read_csv('data-fragile.csv', index_col="Rank")
df.head()
# Out:
#                        Country  2017 score  Change from 2016  \
# Rank
# 1                  South Sudan       113.9               0.1
# 2                      Somalia       113.4               0.6
# 3     Central African Republic       112.6               0.5
# 4                        Yemen       111.1               0.4
# 5                        Sudan       110.6               0.9
#
#       Change from 2015  Change from 2014  Change from 2013  Change from 2012  \
# Rank
# 1                  0.7               0.9               3.2               5.4
# 2                  NaN               1.4               0.1               0.9
# 3                  0.2               1.5               6.8               8.3
# 4                  3.4               6.1               4.5               6.7
# 5                  0.7               1.4               0.5               2.1
#
#       Change from 2011 Continent
# Rank
# 1                  NaN    Africa
# 2                  0.6    Africa
# 3                  7.1    Africa
# 4                 11.2    Africa
# 5                  2.8    Africa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 178 entries, 1 to 178
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country           178 non-null    object
#  1   2017 score        178 non-null    float64
#  2   Change from 2016  173 non-null    float64
#  3   Change from 2015  173 non-null    float64
#  4   Change from 2014  177 non-null    float64
#  5   Change from 2013  177 non-null    float64
#  6   Change from 2012  177 non-null    float64
#  7   Change from 2011  176 non-null    float64
#  8   Continent         178 non-null    object
# dtypes: float64(7), object(2)
# memory usage: 13.9+ KB

# %% [markdown]
# ### Creating a bar plot of top 20 unstable countries

# %%
sns.barplot(y="Country", x="2017 score", data=df[:20]);

# %% [markdown]
# ### Visualizing Top 20 least unstable countries

# %%
sns.barplot(y="Country", x="2017 score", data=df[-20:]);

# %% [markdown]
# ### Categorizing and Visualizing data by continent

# %%
sns.stripplot(x="Continent", y="2017 score", data=df);

# %%
sns.boxplot(x="Continent", y="2017 score", data=df);

# %% [markdown]
# ### Customizations

# %%
sns.boxplot(x="Continent", y="2017 score", data=df);

# %%
sns.set_style("whitegrid")

# %%
sns.boxplot(x="Continent", y="2017 score", data=df);

# %%
sns.set_style('dark')

# %%
sns.boxplot(x="Continent", y="2017 score", data=df);

# %% [markdown]
# #### Removing axis spines

# %%
sns.set_style("whitegrid")
sns.boxplot(x="Continent", y="2017 score", data=df)
sns.despine(left=True)
# Out:
# <AxesSubplot:xlabel='Continent', ylabel='2017 score'>

# %% [markdown]
# ### Grids

# %%
g = sns.FacetGrid(df, col="Continent")
g.map(plt.hist, "2017 score");
g.add_legend
# Out:
# <bound method Grid.add_legend of <seaborn.axisgrid.FacetGrid object at 0x000000DFB6BECCA0>>
